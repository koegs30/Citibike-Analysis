# %%
import pandas as pd
import glob
import random
import numpy as np
import csv
import datetime

# %%
path = 'Resources/Citibike_csvs4'
all_files = glob.glob(path + "/*.csv")

randos = []

for filename in all_files:
    with open(filename, encoding='utf8') as source:
        lines = [line for line in source]
#         random_choice = random.sample(lines, 2000)
        for line in lines[1:]:
          randos.append(line)
randos
# Out:
# ['"404","2014-07-01 00:00:04","2014-07-01 00:06:48","545","E 23 St & 1 Ave","40.736502","-73.97809472","402","Broadway & E 22 St","40.7403432","-73.98955109","19578","Subscriber","1987","2"\n',
#  '"850","2014-07-01 00:00:06","2014-07-01 00:14:16","238","Bank St & Washington St","40.7361967","-74.00859207","458","11 Ave & W 27 St","40.751396","-74.005226","19224","Subscriber","1987","1"\n',
#  '"1550","2014-07-01 00:00:21","2014-07-01 00:26:11","223","W 13 St & 7 Ave","40.73781509","-73.99994661","539","Metropolitan Ave & Bedford Ave","40.71534825","-73.96024116","17627","Subscriber","1973","2"\n',
#  '"397","2014-07-01 00:00:29","2014-07-01 00:07:06","224","Spruce St & Nassau St","40.71146364","-74.00552427","2008","Little West St & 1 Pl","40.70569254","-74.01677685","15304","Subscriber","1982","1"\n',
# ...

# %%
all_randoms_df = pd.DataFrame(randos)

all_randoms_df.head()
# Out:
#                                                    0
# 0  "404","2014-07-01 00:00:04","2014-07-01 00:06:...
# 1  "850","2014-07-01 00:00:06","2014-07-01 00:14:...
# 2  "1550","2014-07-01 00:00:21","2014-07-01 00:26...
# 3  "397","2014-07-01 00:00:29","2014-07-01 00:07:...
# 4  "609","2014-07-01 00:00:37","2014-07-01 00:10:...

# %%
all_randoms_df = all_randoms_df[0].str.split(",",expand=True,)
all_randoms_df.head()
# Out:
#         0                      1                      2      3  \
# 0   "404"  "2014-07-01 00:00:04"  "2014-07-01 00:06:48"  "545"
# 1   "850"  "2014-07-01 00:00:06"  "2014-07-01 00:14:16"  "238"
# 2  "1550"  "2014-07-01 00:00:21"  "2014-07-01 00:26:11"  "223"
# 3   "397"  "2014-07-01 00:00:29"  "2014-07-01 00:07:06"  "224"
# 4   "609"  "2014-07-01 00:00:37"  "2014-07-01 00:10:46"  "346"
#
#                            4              5               6       7  \
# 0          "E 23 St & 1 Ave"    "40.736502"  "-73.97809472"   "402"
# 1  "Bank St & Washington St"   "40.7361967"  "-74.00859207"   "458"
# 2          "W 13 St & 7 Ave"  "40.73781509"  "-73.99994661"   "539"
# 3    "Spruce St & Nassau St"  "40.71146364"  "-74.00552427"  "2008"
# 4      "Bank St & Hudson St"  "40.73652889"  "-74.00618026"   "521"
#
#                                   8              9              10       11  \
# 0              "Broadway & E 22 St"   "40.7403432"  "-73.98955109"  "19578"
# ...

# %%
all_randoms_df.columns = ['trip_duration','start_time','stop_time','start_station_id','start_station_name','start_station_latitude','start_station_longitude','end_station_id','end_station_name','end_station_latitude','end_station_longitude','bikeid','usertype','birth_year','gender']
all_randoms_df.head()
# Out:
#   trip_duration             start_time              stop_time  \
# 0         "404"  "2014-07-01 00:00:04"  "2014-07-01 00:06:48"
# 1         "850"  "2014-07-01 00:00:06"  "2014-07-01 00:14:16"
# 2        "1550"  "2014-07-01 00:00:21"  "2014-07-01 00:26:11"
# 3         "397"  "2014-07-01 00:00:29"  "2014-07-01 00:07:06"
# 4         "609"  "2014-07-01 00:00:37"  "2014-07-01 00:10:46"
#
#   start_station_id         start_station_name start_station_latitude  \
# 0            "545"          "E 23 St & 1 Ave"            "40.736502"
# 1            "238"  "Bank St & Washington St"           "40.7361967"
# 2            "223"          "W 13 St & 7 Ave"          "40.73781509"
# 3            "224"    "Spruce St & Nassau St"          "40.71146364"
# 4            "346"      "Bank St & Hudson St"          "40.73652889"
#
#   start_station_longitude end_station_id                  end_station_name  \
# 0          "-73.97809472"          "402"              "Broadway & E 22 St"
# ...

# %%
all_randoms_df = all_randoms_df.replace('"', ' ', regex=True)

# %%
all_randoms_df
# Out:
#         trip_duration                  start_time                   stop_time  \
# 0                404         2014-07-01 00:00:04         2014-07-01 00:06:48
# 1                850         2014-07-01 00:00:06         2014-07-01 00:14:16
# 2               1550         2014-07-01 00:00:21         2014-07-01 00:26:11
# 3                397         2014-07-01 00:00:29         2014-07-01 00:07:06
# 4                609         2014-07-01 00:00:37         2014-07-01 00:10:46
# ...               ...                         ...                         ...
# 5063526           644   2019-07-31 23:59:45.2950    2019-08-01 00:10:29.8640
# 5063527           589   2019-07-31 23:59:52.7170    2019-08-01 00:09:42.0870
# 5063528          1302   2019-07-31 23:59:52.8280    2019-08-01 00:21:35.1090
# 5063529           353   2019-07-31 23:59:57.1130    2019-08-01 00:05:50.1350
# 5063530           274   2019-07-31 23:59:57.4870    2019-08-01 00:04:32.2070
#
# ...

# %%
all_randoms_df["start_time"]= pd.to_datetime(all_randoms_df["start_time"])
all_randoms_df["stop_time"]= pd.to_datetime(all_randoms_df["stop_time"])
all_randoms_df
# Out:
#         trip_duration              start_time               stop_time  \
# 0                404  2014-07-01 00:00:04.000 2014-07-01 00:06:48.000
# 1                850  2014-07-01 00:00:06.000 2014-07-01 00:14:16.000
# 2               1550  2014-07-01 00:00:21.000 2014-07-01 00:26:11.000
# 3                397  2014-07-01 00:00:29.000 2014-07-01 00:07:06.000
# 4                609  2014-07-01 00:00:37.000 2014-07-01 00:10:46.000
# ...               ...                     ...                     ...
# 5063526           644 2019-07-31 23:59:45.295 2019-08-01 00:10:29.864
# 5063527           589 2019-07-31 23:59:52.717 2019-08-01 00:09:42.087
# 5063528          1302 2019-07-31 23:59:52.828 2019-08-01 00:21:35.109
# 5063529           353 2019-07-31 23:59:57.113 2019-08-01 00:05:50.135
# 5063530           274 2019-07-31 23:59:57.487 2019-08-01 00:04:32.207
#
#         start_station_id                start_station_name  \
# 0                   545                   E 23 St & 1 Ave
# ...

# %%
all_randoms_df.tail()
# Out:
#         trip_duration              start_time               stop_time  \
# 5063526           644 2019-07-31 23:59:45.295 2019-08-01 00:10:29.864
# 5063527           589 2019-07-31 23:59:52.717 2019-08-01 00:09:42.087
# 5063528          1302 2019-07-31 23:59:52.828 2019-08-01 00:21:35.109
# 5063529           353 2019-07-31 23:59:57.113 2019-08-01 00:05:50.135
# 5063530           274 2019-07-31 23:59:57.487 2019-08-01 00:04:32.207
#
#         start_station_id                start_station_name  \
# 5063526              274   Lafayette Ave & Fort Greene Pl
# 5063527             3285          W 87 St & Amsterdam Ave
# 5063528              331              Pike St & Monroe St
# 5063529             3255                  8 Ave & W 31 St
# 5063530             3459                  E 53 St & 3 Ave
#
#         start_station_latitude start_station_longitude end_station_id  \
# 5063526            40.68691865              -73.976682           3409
# ...

# %%
all_randoms_df.to_csv('citi_bikes_select141819July.csv')
